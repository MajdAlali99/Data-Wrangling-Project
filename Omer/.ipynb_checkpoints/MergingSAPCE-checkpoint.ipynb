# %%
import pandas as pd
import os
import glob
import matplotlib.pyplot as plt

# %%
#read the path
file_path = "../SAPCE"
file_list = os.listdir(file_path)
# locate .csv
csv_files = glob.glob('../SAPCE/*.{}'.format('csv'))
csv_files = [i[9:] for i in csv_files if 'ALL_AREAS' in i]
# merge
  
df_concat = pd.concat([pd.read_csv(f'../SAPCE/{f}') for f in csv_files ], ignore_index=True)
df_concat = df_concat.iloc[:-4].fillna(0)

# %%
df_concat = df_concat[df_concat.TableName != 'SASUMMARY']
df_concat = df_concat[df_concat.TableName != 0]
df_concat['Region'] = df_concat['Region'].replace(' ','0')
cols = list(range(1998,2022))
cols = [str(i) for i in cols]
df_concat[cols] = df_concat[cols].apply(pd.to_numeric, errors='coerce').fillna(0)

# %%
df_concat.head()
# Out:
#     GeoFIPS        GeoName Region TableName  LineCode IndustryClassification  \
# 0   "00000"  United States      0    SAPCE1       1.0                    ...
# 1   "00000"  United States      0    SAPCE1       2.0                    ...
# 2   "00000"  United States      0    SAPCE1       3.0                    ...
# 3   "00000"  United States      0    SAPCE1       4.0                    ...
# 4   "00000"  United States      0    SAPCE1       5.0                    ...
#
#                                        Description  \
# 0               Personal consumption expenditures
# 1                                           Goods
# 2                                   Durable goods
# 3                        Motor vehicles and parts
# 4     Furnishings and durable household equipment
#
#                           Unit       1997       1998  ...        2012  \
# 0  Millions of current dollars  5536790.1  5877248.2  ...  11047363.2
# 1  Millions of current dollars  2006505.5  2108439.4  ...   3637739.2
# 2  Millions of current dollars   715529.6   779293.4  ...   1144221.0
# 3  Millions of current dollars   293082.5   320204.7  ...    396607.9
# 4  Millions of current dollars   160490.2   173579.1  ...    253938.0
#
#          2013        2014        2015        2016        2017        2018  \
# 0  11363527.8  11847725.1  12263476.3  12693265.6  13233608.6  13904979.5
# 1   3729972.7   3862956.5   3922992.5   3991848.9   4159375.0   4355177.3
# 2   1189413.3   1242075.5   1307605.2   1345193.9   1398248.0   1470686.8
# 3    417533.0    441992.0    475346.0    484318.5    502150.2    520875.0
# 4    263589.7    276166.5    294219.7    308489.1    322796.3    346025.8
#
#          2019        2020        2021
# 0  14392721.0  14116165.7  15902575.3
# 1   4473509.9   4670135.0   5496516.0
# 2   1510542.9   1646793.0   2060246.3
# 3    517001.3    533928.4    688718.9
# 4    360456.0    411923.1    495001.7
#
# [5 rows x 33 columns]

# %%
df_concat.drop('LineCode', axis=1).groupby('Region').sum().T.sort_index(axis=0).plot(figsize=(8,5));

# %%
# save to csv

# df_concat.to_csv('Final-SAPCE-dataset.csv')

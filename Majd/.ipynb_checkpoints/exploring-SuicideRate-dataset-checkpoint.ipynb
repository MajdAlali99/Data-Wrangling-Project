# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
suicide = pd.read_csv('../datasets/Suicide-rate.csv')

# %%
suicide
# Out:
#      YEAR STATE  RATE DEATHS  \
# 0    2020    AL  16.0    793
# 1    2020    AK  27.5    204
# 2    2020    AZ  17.6   1363
# 3    2020    AR  19.0    583
# 4    2020    CA  10.0   4144
# ..    ...   ...   ...    ...
# 395  2005    VA  11.2    866
# 396  2005    WA  12.8    822
# 397  2005    WV  13.2    255
# 398  2005    WI  11.6    643
# 399  2005    WY  17.3     90
#
#                                                    URL
# 0                /nchs/pressroom/states/alabama/al.htm
# 1                 /nchs/pressroom/states/alaska/ak.htm
# 2                /nchs/pressroom/states/arizona/az.htm
# 3               /nchs/pressroom/states/arkansas/ar.htm
# 4             /nchs/pressroom/states/california/ca.htm
# ..                                                 ...
# 395       /nchs/pressroom/states/virginia/virginia.htm
# 396   /nchs/pressroom/states/washington/washington.htm
# 397  /nchs/pressroom/states/westvirginia/westvirgin...
# ...

# %%
suicide.groupby(['YEAR', 'STATE']).sum().unstack(0)#.plot()
# plt.legend(loc=(1.04, 0));
# Out:
#        RATE
# YEAR   2005  2014  2015  2016  2017  2018  2019  2020
# STATE
# AK     19.9  22.1  26.9  25.8  27.0  24.6  28.5  27.5
# AL     11.5  14.5  14.9  15.7  16.6  16.5  16.3  16.0
# AR     14.3  17.3  19.1  18.2  20.8  18.3  18.0  19.0
# AZ     16.4  18.0  18.2  17.7  18.2  19.2  18.7  17.6
# CA      9.1  10.5  10.3  10.5  10.5  10.9  10.7  10.0
# CO     17.2  19.9  19.5  20.5  20.3  21.9  22.1  21.5
# CT      8.1   9.8   9.9  10.1  10.5  10.6  11.4   9.3
# DE      9.7  13.2  12.6  11.5  11.6  11.4  11.3  12.3
# FL     12.5  13.9  14.4  14.0  14.0  15.2  14.5  13.2
# GA     10.6  12.6  12.7  13.3  13.6  14.6  14.6  13.7
# HI      8.2  13.8  13.5  12.1  15.2  11.9  15.5  12.9
# IA     11.2  12.9  13.9  14.6  15.0  15.5  16.7  18.0
# ID     16.5  20.0  22.1  21.4  23.2  23.9  20.4  23.2
# IL      8.6  10.5  10.3  10.7  11.2  11.3  10.9  10.5
# IN     11.8  14.3  14.4  15.4  16.3  16.0  14.2  15.0
# KS     13.3  15.7  16.3  17.9  19.1  19.3  18.2  18.4
# ...

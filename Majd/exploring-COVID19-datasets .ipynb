# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
death = pd.read_csv('../datasets/covid_deaths_usafacts.csv')
cases = pd.read_csv('../datasets/covid_confirmed_usafacts.csv')
population = pd.read_csv('../datasets/covid_county_population_usafacts.csv')

# %%
State_grouped = death.drop(['countyFIPS','StateFIPS'], axis=1).groupby('State').sum()

# %%
State_grouped.T.plot(figsize=(7,4))
plt.legend(loc=(1.04, 0));
